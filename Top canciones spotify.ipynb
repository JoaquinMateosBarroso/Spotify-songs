# %% [markdown]
# ### Análisis de las canciones más escuchadas entre 2010 y 2019

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 1. Guía
#
# 1. [Primer vistazo a los datos](#primer_vistazo)
#
#
# 99. [Referencias](#referencias)

# %% [markdown]
# #### 2. Primer vistazo a los datos

# %% [markdown]
# Veamos primero cuáles son los 10 álbumes más escuchados, y junto a ellos toda la información que tenemos de cada álbum

# %%
df = pd.read_csv("top10s.csv", encoding='latin')
df.head(10)
# Out:
#     Unnamed: 0                                       title  \
# 0            1                            Hey, Soul Sister
# 1            2                        Love The Way You Lie
# 2            3                                     TiK ToK
# 3            4                                 Bad Romance
# 4            5                        Just the Way You Are
# 5            6                                        Baby
# 6            7                                    Dynamite
# 7            8                                     Secrets
# 8            9  Empire State of Mind (Part II) Broken Down
# 9           10                    Only Girl (In The World)
# 10          11   Club Can't Handle Me (feat. David Guetta)
# 11          12                                   Marry You
# 12          13                 Cooler Than Me - Single Mix
# 13          14                                   Telephone
# 14          15                                   Like A G6
# 15          16                       OMG (feat. will.i.am)
# 16          17                                Eenie Meenie
# 17          18                        The Time (Dirty Bit)
# 18          19                                   Alejandro
# 19          20                        Your Love Is My Drug
#
#                  artist        top genre  year  bpm  nrgy  dnce  dB  live  \
# 0                 Train       neo mellow  2010   97    89    67  -4     8
# 1                Eminem  detroit hip hop  2010   87    93    75  -5    52
# 2                 Kesha        dance pop  2010  120    84    76  -3    29
# 3             Lady Gaga        dance pop  2010  119    92    70  -4     8
# 4            Bruno Mars              pop  2010  109    84    64  -5     9
# 5         Justin Bieber     canadian pop  2010   65    86    73  -5    11
# 6             Taio Cruz        dance pop  2010  120    78    75  -4     4
# 7           OneRepublic        dance pop  2010  148    76    52  -6    12
# 8           Alicia Keys          hip pop  2010   93    37    48  -8    12
# 9               Rihanna    barbadian pop  2010  126    72    79  -4     7
# 10             Flo Rida        dance pop  2010  128    87    62  -4     6
# 11           Bruno Mars              pop  2010  145    83    62  -5    10
# 12          Mike Posner        dance pop  2010  130    82    77  -5    70
# 13            Lady Gaga        dance pop  2010  122    83    83  -6    11
# 14    Far East Movement        dance pop  2010  125    84    44  -8    12
# 15                Usher      atl hip hop  2010  130    75    78  -6    36
# 16        Sean Kingston        dance pop  2010  121    61    72  -4    11
# 17  The Black Eyed Peas        dance pop  2010  128    81    82  -8    60
# 18            Lady Gaga        dance pop  2010   99    80    63  -7    36
# 19                Kesha        dance pop  2010  120    61    83  -4     9
#
#     val  dur  acous  spch  pop
# 0    80  217     19     4   83
# 1    64  263     24    23   82
# 2    71  200     10    14   80
# 3    71  295      0     4   79
# 4    43  221      2     4   78
# 5    54  214      4    14   77
# 6    82  203      0     9   77
# 7    38  225      7     4   77
# 8    14  216     74     3   76
# 9    61  235     13     4   73
# 10   47  235      3     3   73
# 11   48  230     33     4   73
# 12   63  213     18     5   73
# 13   71  221      1     4   73
# 14   78  217      1    45   72
# 15   33  269     20     3   72
# 16   83  202      5     3   71
# 17   44  308      7     7   70
# 18   37  274      0     5   69
# 19   76  187      1    10   69

# %% [markdown]
# #### 99. Referencias

# %% [markdown]
# <html><a id='referencias'></a></html>
# El archivo usado para el análsis ha sido extraído de la plataforma de bases de datos kaggle, que es open source, por lo que tenemos todo el derecho a hacer lo que queramos con los datos.<br>
# Adjunto link a la base de datos <a href="https://www.kaggle.com/datasets/leonardopena/top-spotify-songs-from-20102019-by-year/code" target="_blank">aquí</a>.
